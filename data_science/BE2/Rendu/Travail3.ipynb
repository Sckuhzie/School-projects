# %% [markdown]
# # Travail 3

# %%
from scipy.io import arff
import pandas as pd
import wittgenstein as lw

from prism_rules import PrismRules
from mlxtend.frequent_patterns import apriori, association_rules

# %% [markdown]
# ## Base Champignon

# %%
file = "datasets/mushrooms_weka_training.arff"

arff_file = arff.loadarff(file)
data = pd.DataFrame(arff_file[0])

data = data.map(lambda x: x.decode() if isinstance(x, bytes) else x)
data
# Out:
#      cap-shape cap-surface cap-color bruises? odor gill-attachment  \
# 0            x           s         n        t    p               f
# 1            x           s         y        t    a               f
# 2            b           s         w        t    l               f
# 3            x           y         w        t    p               f
# 4            x           s         g        f    n               f
# ...        ...         ...       ...      ...  ...             ...
# 6995         f           y         e        f    s               f
# 6996         k           y         e        f    s               f
# 6997         k           f         w        f    n               f
# 6998         x           s         g        f    n               f
# 6999         k           s         n        f    n               a
#
#      gill-spacing gill-size gill-color stalk-shape  ...  \
# 0               c         n          k           e  ...
# 1               c         b          k           e  ...
# 2               c         b          n           e  ...
# 3               c         n          n           e  ...
# 4               w         b          k           t  ...
# ...           ...       ...        ...         ...  ...
# 6995            c         n          b           t  ...
# 6996            c         n          b           t  ...
# 6997            w         b          p           e  ...
# 6998            w         b          w           e  ...
# 6999            c         b          y           e  ...
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 6995                      p                      w         p          w
# 6996                      w                      p         p          w
# 6997                      w                      w         p          w
# 6998                      w                      w         p          w
# 6999                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat class
# 0              o         p                 k          s       u     p
# 1              o         p                 n          n       g     e
# 2              o         p                 n          n       m     e
# 3              o         p                 k          s       u     p
# 4              o         e                 n          a       g     e
# ...          ...       ...               ...        ...     ...   ...
# 6995           o         e                 w          v       d     p
# 6996           o         e                 w          v       d     p
# 6997           t         p                 w          s       g     e
# 6998           t         p                 w          s       g     e
# 6999           o         p                 o          v       l     e
#
# [7000 rows x 23 columns]

# %%
X = data.drop(columns='class')
y = data['class']

# %% [markdown]
# ### Méthode Ripper

# %%
ripper_clf = lw.RIPPER() # Or irep_clf = lw.IREP() to build a model using IREP
ripper_clf.fit(X, y, pos_class="e") # Or pass X and y data to .fit
ripper_clf.out_model()
# Out:
# [[odor=n ^ stalk-shape=t] V
# [bruises?=t ^ stalk-root=c] V
# [odor=n ^ habitat=w] V
# [odor=n ^ bruises?=f ^ stalk-surface-above-ring=s] V
# [stalk-root=r] V
# [gill-spacing=w ^ stalk-shape=t] V
# [odor=n ^ gill-spacing=w ^ bruises?=f] V
# [ring-number=t ^ cap-shape=x] V
# [ring-number=t ^ cap-color=n]]

# %% [markdown]
# ### Méthode Prism

# %%
prism = PrismRules()

rules = prism.get_prism_rules(data, "class")
# Out:
# ........................................................................
# Target: p
# ........................................................................
# odor = f
#    Support:  the target has value: 'p' for 100.000% of the 1952 rows matching the rule
#    Coverage: the rule matches: 1952 out of 3256 rows for target value: 'p'. This is:
#       59.951% of total rows for target value: 'p'
#       27.886% of total rows in data
# gill-color = b
#    Support:  The target has value: 'p' for 100.000% of the 738 remaining rows matching the rule
#    Coverage: The rule matches: 738 out of 1304 rows remaining for target value: 'p'. This is:
#       56.595% of remaining rows for target value: 'p'
#       22.666% of total rows for target value: 'p'
#       10.543% of total rows in data
# odor = p
#    Support:  The target has value: 'p' for 100.000% of the 256 remaining rows matching the rule
#    Coverage: The rule matches: 256 out of 566 rows remaining for target value: 'p'. This is:
#       45.230% of remaining rows for target value: 'p'
#       7.862% of total rows for target value: 'p'
#       3.657% of total rows in data
# odor = c
#    Support:  The target has value: 'p' for 100.000% of the 192 remaining rows matching the rule
#    Coverage: The rule matches: 192 out of 310 rows remaining for target value: 'p'. This is:
#       61.935% of remaining rows for target value: 'p'
#       5.897% of total rows for target value: 'p'
#       2.743% of total rows in data
# spore-print-color = r
#    Support:  The target has value: 'p' for 100.000% of the 72 remaining rows matching the rule
#    Coverage: The rule matches: 72 out of 118 rows remaining for target value: 'p'. This is:
#       61.017% of remaining rows for target value: 'p'
#       2.211% of total rows for target value: 'p'
#       1.029% of total rows in data
# stalk-color-below-ring = y
#    Support:  The target has value: 'p' for 100.000% of the 17 remaining rows matching the rule
#    Coverage: The rule matches: 17 out of 46 rows remaining for target value: 'p'. This is:
#       36.957% of remaining rows for target value: 'p'
#       0.522% of total rows for target value: 'p'
#       0.243% of total rows in data
# stalk-surface-above-ring = k AND gill-spacing = c
#    Support:  The target has value: 'p' for 100.000% of the 21 remaining rows matching the rule
#    Coverage: The rule matches: 21 out of 29 rows remaining for target value: 'p'. This is:
#       72.414% of remaining rows for target value: 'p'
#       0.645% of total rows for target value: 'p'
#       0.300% of total rows in data
#
# ........................................................................
# Target: e
# ........................................................................
# stalk-color-above-ring = g
#    Support:  the target has value: 'e' for 100.000% of the 576 rows matching the rule
#    Coverage: the rule matches: 576 out of 3744 rows for target value: 'e'. This is:
#       15.385% of total rows for target value: 'e'
#       8.229% of total rows in data
# odor = a
#    Support:  The target has value: 'e' for 100.000% of the 400 remaining rows matching the rule
#    Coverage: The rule matches: 400 out of 3168 rows remaining for target value: 'e'. This is:
#       12.626% of remaining rows for target value: 'e'
#       10.684% of total rows for target value: 'e'
#       5.714% of total rows in data
# odor = l
#    Support:  The target has value: 'e' for 100.000% of the 400 remaining rows matching the rule
#    Coverage: The rule matches: 400 out of 2768 rows remaining for target value: 'e'. This is:
#       14.451% of remaining rows for target value: 'e'
#       10.684% of total rows for target value: 'e'
#       5.714% of total rows in data
# stalk-color-below-ring = g
#    Support:  The target has value: 'e' for 100.000% of the 384 remaining rows matching the rule
#    Coverage: The rule matches: 384 out of 2368 rows remaining for target value: 'e'. This is:
#       16.216% of remaining rows for target value: 'e'
#       10.256% of total rows for target value: 'e'
#       5.486% of total rows in data
# population = a
#    Support:  The target has value: 'e' for 100.000% of the 384 remaining rows matching the rule
#    Coverage: The rule matches: 384 out of 1984 rows remaining for target value: 'e'. This is:
#       19.355% of remaining rows for target value: 'e'
#       10.256% of total rows for target value: 'e'
#       5.486% of total rows in data
# habitat = w
#    Support:  The target has value: 'e' for 100.000% of the 192 remaining rows matching the rule
#    Coverage: The rule matches: 192 out of 1600 rows remaining for target value: 'e'. This is:
#       12.000% of remaining rows for target value: 'e'
#       5.128% of total rows for target value: 'e'
#       2.743% of total rows in data
# ring-type = f
#    Support:  The target has value: 'e' for 100.000% of the 48 remaining rows matching the rule
#    Coverage: The rule matches: 48 out of 1408 rows remaining for target value: 'e'. This is:
#       3.409% of remaining rows for target value: 'e'
#       1.282% of total rows for target value: 'e'
#       0.686% of total rows in data
# cap-shape = s
#    Support:  The target has value: 'e' for 100.000% of the 32 remaining rows matching the rule
#    Coverage: The rule matches: 32 out of 1360 rows remaining for target value: 'e'. This is:
#       2.353% of remaining rows for target value: 'e'
#       0.855% of total rows for target value: 'e'
#       0.457% of total rows in data
# population = n
#    Support:  The target has value: 'e' for 100.000% of the 19 remaining rows matching the rule
#    Coverage: The rule matches: 19 out of 1328 rows remaining for target value: 'e'. This is:
#       1.431% of remaining rows for target value: 'e'
#       0.507% of total rows for target value: 'e'
#       0.271% of total rows in data
# stalk-color-above-ring = o
#    Support:  The target has value: 'e' for 100.000% of the 16 remaining rows matching the rule
#    Coverage: The rule matches: 16 out of 1309 rows remaining for target value: 'e'. This is:
#       1.222% of remaining rows for target value: 'e'
#       0.427% of total rows for target value: 'e'
#       0.229% of total rows in data
# cap-color = c AND odor = n
#    Support:  The target has value: 'e' for 100.000% of the 26 remaining rows matching the rule
#    Coverage: The rule matches: 26 out of 1293 rows remaining for target value: 'e'. This is:
#       2.011% of remaining rows for target value: 'e'
#       0.694% of total rows for target value: 'e'
#       0.371% of total rows in data
# odor = n AND stalk-shape = t
#    Support:  The target has value: 'e' for 100.000% of the 1152 remaining rows matching the rule
#    Coverage: The rule matches: 1152 out of 1267 rows remaining for target value: 'e'. This is:
#       90.923% of remaining rows for target value: 'e'
#       30.769% of total rows for target value: 'e'
#       16.457% of total rows in data
# odor = n AND stalk-root = e
#    Support:  The target has value: 'e' for 100.000% of the 64 remaining rows matching the rule
#    Coverage: The rule matches: 64 out of 115 rows remaining for target value: 'e'. This is:
#       55.652% of remaining rows for target value: 'e'
#       1.709% of total rows for target value: 'e'
#       0.914% of total rows in data
# odor = n AND population = s
#    Support:  The target has value: 'e' for 100.000% of the 22 remaining rows matching the rule
#    Coverage: The rule matches: 22 out of 51 rows remaining for target value: 'e'. This is:
#       43.137% of remaining rows for target value: 'e'
#       0.588% of total rows for target value: 'e'
#       0.314% of total rows in data
# odor = n AND stalk-surface-above-ring = f
#    Support:  The target has value: 'e' for 100.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 29 rows remaining for target value: 'e'. This is:
#       41.379% of remaining rows for target value: 'e'
#       0.321% of total rows for target value: 'e'
#       0.171% of total rows in data
# odor = n AND gill-spacing = w AND cap-color = n
#    Support:  The target has value: 'e' for 100.000% of the 12 remaining rows matching the rule
#    Coverage: The rule matches: 12 out of 17 rows remaining for target value: 'e'. This is:
#       70.588% of remaining rows for target value: 'e'
#       0.321% of total rows for target value: 'e'
#       0.171% of total rows in data

# %% [markdown]
# ### Méthode Apriori

# %%
data_train_dummies = pd.get_dummies(data)
data_train_dummies
# Out:
#       cap-shape_b  cap-shape_c  cap-shape_f  cap-shape_k  cap-shape_s  \
# 0           False        False        False        False        False
# 1           False        False        False        False        False
# 2            True        False        False        False        False
# 3           False        False        False        False        False
# 4           False        False        False        False        False
# ...           ...          ...          ...          ...          ...
# 6995        False        False         True        False        False
# 6996        False        False        False         True        False
# 6997        False        False        False         True        False
# 6998        False        False        False        False        False
# 6999        False        False        False         True        False
#
#       cap-shape_x  cap-surface_f  cap-surface_g  cap-surface_s  cap-surface_y  \
# 0            True          False          False           True          False
# 1            True          False          False           True          False
# 2           False          False          False           True          False
# 3            True          False          False          False           True
# 4            True          False          False           True          False
# ...           ...            ...            ...            ...            ...
# 6995        False          False          False          False           True
# 6996        False          False          False          False           True
# 6997        False           True          False          False          False
# 6998         True          False          False           True          False
# 6999        False          False          False           True          False
#
#       ...  population_y  habitat_d  habitat_g  habitat_l  habitat_m  \
# 0     ...         False      False      False      False      False
# 1     ...         False      False       True      False      False
# 2     ...         False      False      False      False       True
# 3     ...         False      False      False      False      False
# 4     ...         False      False       True      False      False
# ...   ...           ...        ...        ...        ...        ...
# 6995  ...         False       True      False      False      False
# 6996  ...         False       True      False      False      False
# 6997  ...         False      False       True      False      False
# 6998  ...         False      False       True      False      False
# 6999  ...         False      False      False       True      False
#
#       habitat_p  habitat_u  habitat_w  class_e  class_p
# 0         False       True      False    False     True
# 1         False      False      False     True    False
# 2         False      False      False     True    False
# 3         False       True      False    False     True
# 4         False      False      False     True    False
# ...         ...        ...        ...      ...      ...
# 6995      False      False      False    False     True
# 6996      False      False      False    False     True
# 6997      False      False      False     True    False
# 6998      False      False      False     True    False
# 6999      False      False      False     True    False
#
# [7000 rows x 119 columns]

# %%
frequent_itemsets = apriori(data_train_dummies, min_support=0.40, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets = frequent_itemsets[frequent_itemsets['length'] < 5]
# frequent_itemsets[frequent_itemsets["support"] > 0.7]

frequent_itemsets = frequent_itemsets.sort_values(by='support', ascending=False)
frequent_itemsets

# frequent_itemsets_with_class_e = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: 'class_e' in x)]
# frequent_itemsets_with_class_e = frequent_itemsets_with_class_e.sort_values(by='support', ascending=False)
# frequent_itemsets_with_class_e

# frequent_itemsets_with_class_p = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: 'class_p' in x)]
# frequent_itemsets_with_class_p = frequent_itemsets_with_class_p.sort_values(by='support', ascending=False)
# frequent_itemsets_with_class_p

# attribute_filter = "class_e"
# frequent_itemsets_filtered = frequent_itemsets[frequent_itemsets['itemsets'].apply(lambda x: attribute_filter in x)]
# frequent_itemsets_filtered = frequent_itemsets_filtered.sort_values(by='support', ascending=False)

# frequent_itemsets_filtered = frequent_itemsets_filtered[frequent_itemsets_filtered['length'] > 1]
# frequent_itemsets_filtered
# Out:
#       support                                           itemsets  length
# 16   1.000000                                      (veil-type_p)       1
# 123  0.997571                        (veil-type_p, veil-color_w)       2
# 17   0.997571                                     (veil-color_w)       1
# 6    0.997429                                (gill-attachment_f)       1
# 64   0.997429                   (veil-type_p, gill-attachment_f)       2
# ..        ...                                                ...     ...
# 286  0.400571      (gill-spacing_c, veil-color_w, stalk-shape_e)       3
# 614  0.400571  (gill-spacing_c, veil-type_p, veil-color_w, st...       4
# 492  0.400286  (gill-spacing_c, veil-color_w, stalk-shape_e, ...       4
# 491  0.400286  (gill-spacing_c, veil-type_p, stalk-shape_e, g...       4
# 211  0.400286  (gill-spacing_c, stalk-shape_e, gill-attachmen...       3
#
# [707 rows x 3 columns]

# %%
rules = association_rules(frequent_itemsets, num_itemsets=len(data), metric="lift", min_threshold=1)
rules
# Out:
# c:\Users\paull\miniforge3\envs\env_data_science\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:182: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
#                               antecedents  \
# 0                           (veil-type_p)
# 1                          (veil-color_w)
# 2                           (veil-type_p)
# 3                     (gill-attachment_f)
# 4                          (veil-color_w)
# ...                                   ...
# 4695                      (stalk-shape_e)
# 4696  (gill-spacing_c, gill-attachment_f)
# 4697   (stalk-shape_e, gill-attachment_f)
# 4698                     (gill-spacing_c)
# 4699                      (stalk-shape_e)
#
#                                            consequents  antecedent support  \
# 0                                       (veil-color_w)            1.000000
# 1                                        (veil-type_p)            0.997571
# 2                                  (gill-attachment_f)            1.000000
# 3                                        (veil-type_p)            0.997429
# 4                                  (gill-attachment_f)            0.997571
# ...                                                ...                 ...
# 4695  (gill-spacing_c, veil-type_p, gill-attachment_f)            0.430571
# 4696                                   (stalk-shape_e)            0.846286
# 4697                                  (gill-spacing_c)            0.428000
# 4698                (stalk-shape_e, gill-attachment_f)            0.848857
# 4699               (gill-spacing_c, gill-attachment_f)            0.430571
#
#       consequent support   support  confidence      lift  representativity  \
# 0               0.997571  0.997571    0.997571  1.000000               1.0
# 1               1.000000  0.997571    1.000000  1.000000               1.0
# 2               0.997429  0.997429    0.997429  1.000000               1.0
# 3               1.000000  0.997429    1.000000  1.000000               1.0
# 4               0.997429  0.997286    0.999714  1.002291               1.0
# ...                  ...       ...         ...       ...               ...
# 4695            0.846286  0.400286    0.929662  1.098520               1.0
# 4696            0.430571  0.400286    0.472991  1.098520               1.0
# 4697            0.848857  0.400286    0.935247  1.101772               1.0
# 4698            0.428000  0.400286    0.471558  1.101772               1.0
# 4699            0.846286  0.400286    0.929662  1.098520               1.0
#
#       leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0     0.000000    1.000000       0.000000  0.997571   0.000000    0.998786
# 1     0.000000         inf       0.000000  0.997571   0.000000    0.998786
# 2     0.000000    1.000000       0.000000  0.997429   0.000000    0.998714
# 3     0.000000         inf       0.000000  0.997429   0.000000    0.998714
# 4     0.002279    8.978143       0.941160  0.999570   0.888618    0.999785
# ...        ...         ...            ...       ...        ...         ...
# 4695  0.035899    2.185353       0.157498  0.456649   0.542408    0.701326
# 4696  0.035899    1.080492       0.583447  0.456649   0.074495    0.701326
# 4697  0.036975    2.334144       0.161488  0.456649   0.571577    0.703403
# 4698  0.036975    1.082428       0.611151  0.456649   0.076151    0.703403
# 4699  0.035899    2.185353       0.157498  0.456649   0.542408    0.701326
#
# [4700 rows x 14 columns]

# %%
filter1 = frozenset({'class_e'})
filter2 = frozenset({'class_p'})

filtered_rules = rules[rules['consequents'].apply(lambda x: filter1 == x or filter2 == x)]
filtered_rules.sort_values(by='lift', ascending=False).head(10)
# Out:
#                                             antecedents consequents  \
# 3514                (odor_n, veil-type_p, veil-color_w)   (class_e)
# 3503          (odor_n, veil-color_w, gill-attachment_f)   (class_e)
# 3524                             (odor_n, veil-color_w)   (class_e)
# 3350                                           (odor_n)   (class_e)
# 3352                              (veil-type_p, odor_n)   (class_e)
# 3488           (veil-type_p, odor_n, gill-attachment_f)   (class_e)
# 3498                        (odor_n, gill-attachment_f)   (class_e)
# 4466  (stalk-surface-above-ring_s, ring-number_o, gi...   (class_e)
# 2686  (gill-size_b, veil-type_p, stalk-surface-above...   (class_e)
# 2680          (stalk-surface-above-ring_s, gill-size_b)   (class_e)
#
#       antecedent support  consequent support   support  confidence      lift  \
# 3514            0.434286            0.534857  0.418286    0.963158  1.800776
# 3503            0.434286            0.534857  0.418286    0.963158  1.800776
# 3524            0.434286            0.534857  0.418286    0.963158  1.800776
# 3350            0.436714            0.534857  0.420571    0.963036  1.800547
# 3352            0.436714            0.534857  0.420571    0.963036  1.800547
# 3488            0.434429            0.534857  0.418286    0.962841  1.800184
# 3498            0.434429            0.534857  0.418286    0.962841  1.800184
# 4466            0.425143            0.534857  0.404571    0.951613  1.779191
# 2686            0.466571            0.534857  0.435714    0.933864  1.746007
# 2680            0.466571            0.534857  0.435714    0.933864  1.746007
#
#       representativity  leverage  conviction  zhangs_metric   jaccard  \
# 3514               1.0  0.186005   12.625306       0.786057  0.759336
# 3503               1.0  0.186005   12.625306       0.786057  0.759336
# 3524               1.0  0.186005   12.625306       0.786057  0.759336
# 3350               1.0  0.186992   12.583555       0.789321  0.763288
# 3352               1.0  0.186992   12.583555       0.789321  0.763288
# 3488               1.0  0.185928   12.517694       0.785933  0.759139
# 3498               1.0  0.185928   12.517694       0.785933  0.759139
# 4466               1.0  0.177181    9.612952       0.761836  0.728395
# 2686               1.0  0.186165    7.033132       0.800978  0.770202
# 2680               1.0  0.186165    7.033132       0.800978  0.770202
#
#       certainty  kulczynski
# 3514   0.920794    0.872605
# 3503   0.920794    0.872605
# 3524   0.920794    0.872605
# 3350   0.920531    0.874680
# 3352   0.920531    0.874680
# 3488   0.920113    0.872446
# 3498   0.920113    0.872446
# 4466   0.895974    0.854012
# 2686   0.857816    0.874250
# 2680   0.857816    0.874250

# %% [markdown]
# On remarque que quelque soit la méthode, l'attribut odor=n est très présent pour distinguer la classe "e". Sinon, les règles trouvées sont différentes selon les méthodes.

# %% [markdown]
# ## Base "Zoo"

# %%
file = "datasets/zoo.arff"

arff_file = arff.loadarff(file)
data = pd.DataFrame(arff_file[0])

data = data.map(lambda x: x.decode() if isinstance(x, bytes) else x)
data
# Out:
#        animal   hair feathers   eggs   milk airborne aquatic predator toothed  \
# 0    aardvark   true    false  false   true    false   false     true    true
# 1    antelope   true    false  false   true    false   false    false    true
# 2        bass  false    false   true  false    false    true     true    true
# 3        bear   true    false  false   true    false   false     true    true
# 4        boar   true    false  false   true    false   false     true    true
# ..        ...    ...      ...    ...    ...      ...     ...      ...     ...
# 96    wallaby   true    false  false   true    false   false    false    true
# 97       wasp   true    false   true  false     true   false    false   false
# 98       wolf   true    false  false   true    false   false     true    true
# 99       worm  false    false   true  false    false   false    false   false
# 100      wren  false     true   true  false     true   false    false   false
#
#     backbone breathes venomous   fins  legs   tail domestic catsize  \
# 0       true     true    false  false   4.0  false    false    true
# 1       true     true    false  false   4.0   true    false    true
# 2       true    false    false   true   0.0   true    false   false
# 3       true     true    false  false   4.0  false    false    true
# 4       true     true    false  false   4.0   true    false    true
# ..       ...      ...      ...    ...   ...    ...      ...     ...
# 96      true     true    false  false   2.0   true    false    true
# 97     false     true     true  false   6.0  false    false   false
# 98      true     true    false  false   4.0   true    false    true
# 99     false     true    false  false   0.0  false    false   false
# 100     true     true    false  false   2.0   true    false   false
#
#              type
# 0          mammal
# 1          mammal
# 2            fish
# 3          mammal
# 4          mammal
# ..            ...
# 96         mammal
# 97         insect
# 98         mammal
# 99   invertebrate
# 100          bird
#
# [101 rows x 18 columns]

# %%
# Les labels dans la colonne animal sont uniques (sauf deux lignes pour les "frog"), donc on peut les supprimer
data.drop(columns='animal', inplace=True)

legs = data['legs']
zoo_type = data['type']
data = data.drop(columns='type')
data = data.drop(columns='legs')
data = data.applymap(lambda x: True if x == 'true' else False if x == 'false' else x)

legs = pd.get_dummies(legs)
zoo_type = pd.get_dummies(zoo_type)

data = pd.concat([data, legs, zoo_type], axis=1)
data
# Out:
# C:\Users\paull\AppData\Local\Temp\ipykernel_7444\4189044485.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   data = data.applymap(lambda x: True if x == 'true' else False if x == 'false' else x)
#       hair  feathers   eggs   milk  airborne  aquatic  predator  toothed  \
# 0     True     False  False   True     False    False      True     True
# 1     True     False  False   True     False    False     False     True
# 2    False     False   True  False     False     True      True     True
# 3     True     False  False   True     False    False      True     True
# 4     True     False  False   True     False    False      True     True
# ..     ...       ...    ...    ...       ...      ...       ...      ...
# 96    True     False  False   True     False    False     False     True
# 97    True     False   True  False      True    False     False    False
# 98    True     False  False   True     False    False      True     True
# 99   False     False   True  False     False    False     False    False
# 100  False      True   True  False      True    False     False    False
#
#      backbone  breathes  ...    5.0    6.0    8.0  amphibian   bird   fish  \
# 0        True      True  ...  False  False  False      False  False  False
# 1        True      True  ...  False  False  False      False  False  False
# 2        True     False  ...  False  False  False      False  False   True
# 3        True      True  ...  False  False  False      False  False  False
# 4        True      True  ...  False  False  False      False  False  False
# ..        ...       ...  ...    ...    ...    ...        ...    ...    ...
# 96       True      True  ...  False  False  False      False  False  False
# 97      False      True  ...  False   True  False      False  False  False
# 98       True      True  ...  False  False  False      False  False  False
# 99      False      True  ...  False  False  False      False  False  False
# 100      True      True  ...  False  False  False      False   True  False
#
#      insect  invertebrate  mammal  reptile
# 0     False         False    True    False
# 1     False         False    True    False
# 2     False         False   False    False
# 3     False         False    True    False
# 4     False         False    True    False
# ..      ...           ...     ...      ...
# 96    False         False    True    False
# 97     True         False   False    False
# 98    False         False    True    False
# 99    False          True   False    False
# 100   False         False   False    False
#
# [101 rows x 28 columns]

# %%
frequent_itemsets = apriori(data, min_support=0.5, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))

frequent_itemsets.sort_values(by='support', ascending=False)
# Out:
#      support                    itemsets  length
# 3   0.821782                  (backbone)       1
# 4   0.792079                  (breathes)       1
# 5   0.742574                      (tail)       1
# 9   0.732673            (backbone, tail)       2
# 8   0.683168        (backbone, breathes)       2
# 10  0.603960            (tail, breathes)       2
# 6   0.603960         (backbone, toothed)       2
# 2   0.603960                   (toothed)       1
# 12  0.594059  (backbone, tail, breathes)       3
# 0   0.584158                      (eggs)       1
# 1   0.554455                  (predator)       1
# 7   0.514851             (tail, toothed)       2
# 11  0.514851   (backbone, tail, toothed)       3

# %%
rules = association_rules(frequent_itemsets, num_itemsets=len(data),metric="lift", min_threshold=1)
rules.sort_values(by='lift', ascending=False)
# Out:
#              antecedents           consequents  antecedent support  \
# 0             (backbone)             (toothed)            0.821782
# 1              (toothed)            (backbone)            0.603960
# 13            (backbone)       (tail, toothed)            0.821782
# 12       (tail, toothed)            (backbone)            0.514851
# 7                 (tail)            (backbone)            0.742574
# 6             (backbone)                (tail)            0.821782
# 18      (tail, breathes)            (backbone)            0.603960
# 19            (backbone)      (tail, breathes)            0.821782
# 20                (tail)  (backbone, breathes)            0.742574
# 17  (backbone, breathes)                (tail)            0.683168
# 15             (toothed)      (backbone, tail)            0.603960
# 10      (backbone, tail)             (toothed)            0.732673
# 3              (toothed)                (tail)            0.603960
# 2                 (tail)             (toothed)            0.742574
# 11   (backbone, toothed)                (tail)            0.603960
# 14                (tail)   (backbone, toothed)            0.742574
# 5             (breathes)            (backbone)            0.792079
# 4             (backbone)            (breathes)            0.821782
# 8                 (tail)            (breathes)            0.742574
# 9             (breathes)                (tail)            0.792079
# 16      (backbone, tail)            (breathes)            0.732673
# 21            (breathes)      (backbone, tail)            0.792079
#
#     consequent support   support  confidence      lift  representativity  \
# 0             0.603960  0.603960    0.734940  1.216867               1.0
# 1             0.821782  0.603960    1.000000  1.216867               1.0
# 13            0.514851  0.514851    0.626506  1.216867               1.0
# 12            0.821782  0.514851    1.000000  1.216867               1.0
# 7             0.821782  0.732673    0.986667  1.200643               1.0
# 6             0.742574  0.732673    0.891566  1.200643               1.0
# 18            0.821782  0.594059    0.983607  1.196919               1.0
# 19            0.603960  0.594059    0.722892  1.196919               1.0
# 20            0.683168  0.594059    0.800000  1.171014               1.0
# 17            0.742574  0.594059    0.869565  1.171014               1.0
# 15            0.732673  0.514851    0.852459  1.163491               1.0
# 10            0.603960  0.514851    0.702703  1.163491               1.0
# 3             0.742574  0.514851    0.852459  1.147978               1.0
# 2             0.603960  0.514851    0.693333  1.147978               1.0
# 11            0.742574  0.514851    0.852459  1.147978               1.0
# 14            0.603960  0.514851    0.693333  1.147978               1.0
# 5             0.821782  0.683168    0.862500  1.049548               1.0
# 4             0.792079  0.683168    0.831325  1.049548               1.0
# 8             0.792079  0.603960    0.813333  1.026833               1.0
# 9             0.742574  0.603960    0.762500  1.026833               1.0
# 16            0.792079  0.594059    0.810811  1.023649               1.0
# 21            0.732673  0.594059    0.750000  1.023649               1.0
#
#     leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0   0.107637    1.494149       1.000000  0.734940   0.330723    0.867470
# 1   0.107637         inf       0.450000  0.734940   1.000000    0.867470
# 13  0.091756    1.298946       1.000000  0.626506   0.230145    0.813253
# 12  0.091756         inf       0.367347  0.626506   1.000000    0.813253
# 7   0.122439   13.366337       0.649168  0.880952   0.925185    0.939116
# 6   0.122439    2.374037       0.937688  0.880952   0.578777    0.939116
# 18  0.097736   10.871287       0.415417  0.714286   0.908015    0.853249
# 19  0.097736    1.429186       0.923148  0.714286   0.300301    0.853249
# 20  0.086756    1.584158       0.567308  0.714286   0.368750    0.834783
# 17  0.086756    1.973597       0.460937  0.714286   0.493311    0.834783
# 15  0.072346    1.811881       0.354808  0.626506   0.448087    0.777581
# 10  0.072346    1.332133       0.525641  0.626506   0.249324    0.777581
# 3   0.066366    1.744774       0.325481  0.619048   0.426860    0.772896
# 2   0.066366    1.291433       0.500740  0.619048   0.225667    0.772896
# 11  0.066366    1.744774       0.325481  0.619048   0.426860    0.772896
# 14  0.066366    1.291433       0.500740  0.619048   0.225667    0.772896
# 5   0.032252    1.296130       0.227053  0.734043   0.228472    0.846913
# 4   0.032252    1.232673       0.264895  0.734043   0.188755    0.846913
# 8   0.015783    1.113861       0.101513  0.648936   0.102222    0.787917
# 9   0.015783    1.083898       0.125683  0.648936   0.077404    0.787917
# 16  0.013724    1.099010       0.086420  0.638298   0.090090    0.780405
# 21  0.013724    1.069307       0.111111  0.638298   0.064815    0.780405

# %% [markdown]
# ## Base Credit-g

# %%
file = "datasets/credit-g.arff"

arff_file = arff.loadarff(file)
data = pd.DataFrame(arff_file[0])

data = data.map(lambda x: x.decode() if isinstance(x, bytes) else x)
data
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# 2              education         2096.0              <100      4<=X<7
# 3    furniture/equipment         7882.0              <100      4<=X<7
# 4                new car         4870.0              <100      1<=X<4
# ..                   ...            ...               ...         ...
# 995  furniture/equipment         1736.0              <100      4<=X<7
# 996             used car         3857.0              <100      1<=X<4
# 997             radio/tv          804.0              <100         >=7
# 998             radio/tv         1845.0              <100      1<=X<4
# 999             used car         4576.0        100<=X<500  unemployed
#
#      installment_commitment     personal_status other_parties  ...  \
# 0                       4.0         male single          none  ...
# 1                       2.0  female div/dep/mar          none  ...
# 2                       2.0         male single          none  ...
# 3                       2.0         male single     guarantor  ...
# 4                       3.0         male single          none  ...
# ..                      ...                 ...           ...  ...
# 995                     3.0  female div/dep/mar          none  ...
# 996                     4.0        male div/sep          none  ...
# 997                     4.0         male single          none  ...
# 998                     4.0         male single          none  ...
# 999                     3.0         male single          none  ...
#
#      property_magnitude   age  other_payment_plans   housing existing_credits  \
# 0           real estate  67.0                 none       own              2.0
# 1           real estate  22.0                 none       own              1.0
# 2           real estate  49.0                 none       own              1.0
# 3        life insurance  45.0                 none  for free              1.0
# 4     no known property  53.0                 none  for free              2.0
# ..                  ...   ...                  ...       ...              ...
# 995         real estate  31.0                 none       own              1.0
# 996      life insurance  40.0                 none       own              1.0
# 997                 car  38.0                 none       own              1.0
# 998   no known property  23.0                 none  for free              1.0
# 999                 car  27.0                 none       own              1.0
#
#                            job num_dependents  own_telephone foreign_worker  \
# 0                      skilled            1.0            yes            yes
# 1                      skilled            1.0           none            yes
# 2           unskilled resident            2.0           none            yes
# 3                      skilled            2.0           none            yes
# 4                      skilled            2.0           none            yes
# ..                         ...            ...            ...            ...
# 995         unskilled resident            1.0           none            yes
# 996  high qualif/self emp/mgmt            1.0            yes            yes
# 997                    skilled            1.0           none            yes
# 998                    skilled            1.0            yes            yes
# 999                    skilled            1.0           none            yes
#
#     class
# 0    good
# 1     bad
# 2    good
# 3    good
# 4     bad
# ..    ...
# 995  good
# 996  good
# 997  good
# 998   bad
# 999  good
#
# [1000 rows x 21 columns]

# %%
# Change all the numerical attributes to categorical attributes
data['duration'] = pd.cut(data['duration'], bins=3, labels=["short", "medium", "long"])
data['credit_amount'] = pd.cut(data['credit_amount'], bins=3, labels=["low", "medium", "high"])
data['installment_commitment'] = pd.cut(data['installment_commitment'], bins=3, labels=["low", "medium", "high"])
data['residence_since'] = pd.cut(data['residence_since'], bins=3, labels=["low", "medium", "high"])
data['age'] = pd.cut(data['age'], bins=3, labels=["young", "adult", "old"])
data['existing_credits'] = pd.cut(data['existing_credits'], bins=3, labels=["low", "medium", "high"])
data['num_dependents'] = pd.cut(data['num_dependents'], bins=3, labels=["low", "medium", "high"])

data
# Out:
#     checking_status duration                  credit_history  \
# 0                <0    short  critical/other existing credit
# 1          0<=X<200   medium                   existing paid
# 2       no checking    short  critical/other existing credit
# 3                <0   medium                   existing paid
# 4                <0    short              delayed previously
# ..              ...      ...                             ...
# 995     no checking    short                   existing paid
# 996              <0   medium                   existing paid
# 997     no checking    short                   existing paid
# 998              <0   medium                   existing paid
# 999        0<=X<200   medium  critical/other existing credit
#
#                  purpose credit_amount    savings_status  employment  \
# 0               radio/tv           low  no known savings         >=7
# 1               radio/tv           low              <100      1<=X<4
# 2              education           low              <100      4<=X<7
# 3    furniture/equipment        medium              <100      4<=X<7
# 4                new car           low              <100      1<=X<4
# ..                   ...           ...               ...         ...
# 995  furniture/equipment           low              <100      4<=X<7
# 996             used car           low              <100      1<=X<4
# 997             radio/tv           low              <100         >=7
# 998             radio/tv           low              <100      1<=X<4
# 999             used car           low        100<=X<500  unemployed
#
#     installment_commitment     personal_status other_parties  ...  \
# 0                     high         male single          none  ...
# 1                      low  female div/dep/mar          none  ...
# 2                      low         male single          none  ...
# 3                      low         male single     guarantor  ...
# 4                   medium         male single          none  ...
# ..                     ...                 ...           ...  ...
# 995                 medium  female div/dep/mar          none  ...
# 996                   high        male div/sep          none  ...
# 997                   high         male single          none  ...
# 998                   high         male single          none  ...
# 999                 medium         male single          none  ...
#
#     property_magnitude    age other_payment_plans   housing existing_credits  \
# 0          real estate    old                none       own              low
# 1          real estate  young                none       own              low
# 2          real estate  adult                none       own              low
# 3       life insurance  adult                none  for free              low
# 4    no known property  adult                none  for free              low
# ..                 ...    ...                 ...       ...              ...
# 995        real estate  young                none       own              low
# 996     life insurance  adult                none       own              low
# 997                car  adult                none       own              low
# 998  no known property  young                none  for free              low
# 999                car  young                none       own              low
#
#                            job num_dependents own_telephone foreign_worker  \
# 0                      skilled            low           yes            yes
# 1                      skilled            low          none            yes
# 2           unskilled resident           high          none            yes
# 3                      skilled           high          none            yes
# 4                      skilled           high          none            yes
# ..                         ...            ...           ...            ...
# 995         unskilled resident            low          none            yes
# 996  high qualif/self emp/mgmt            low           yes            yes
# 997                    skilled            low          none            yes
# 998                    skilled            low           yes            yes
# 999                    skilled            low          none            yes
#
#     class
# 0    good
# 1     bad
# 2    good
# 3    good
# 4     bad
# ..    ...
# 995  good
# 996  good
# 997  good
# 998   bad
# 999  good
#
# [1000 rows x 21 columns]

# %%
data_dummies = pd.get_dummies(data)
data_dummies
# Out:
#      checking_status_0<=X<200  checking_status_<0  checking_status_>=200  \
# 0                       False                True                  False
# 1                        True               False                  False
# 2                       False               False                  False
# 3                       False                True                  False
# 4                       False                True                  False
# ..                        ...                 ...                    ...
# 995                     False               False                  False
# 996                     False                True                  False
# 997                     False               False                  False
# 998                     False                True                  False
# 999                      True               False                  False
#
#      checking_status_no checking  duration_short  duration_medium  \
# 0                          False            True            False
# 1                          False           False             True
# 2                           True            True            False
# 3                          False           False             True
# 4                          False            True            False
# ..                           ...             ...              ...
# 995                         True            True            False
# 996                        False           False             True
# 997                         True            True            False
# 998                        False           False             True
# 999                        False           False             True
#
#      duration_long  credit_history_all paid  \
# 0            False                    False
# 1            False                    False
# 2            False                    False
# 3            False                    False
# 4            False                    False
# ..             ...                      ...
# 995          False                    False
# 996          False                    False
# 997          False                    False
# 998          False                    False
# 999          False                    False
#
#      credit_history_critical/other existing credit  \
# 0                                             True
# 1                                            False
# 2                                             True
# 3                                            False
# 4                                            False
# ..                                             ...
# 995                                          False
# 996                                          False
# 997                                          False
# 998                                          False
# 999                                           True
#
#      credit_history_delayed previously  ...  job_unskilled resident  \
# 0                                False  ...                   False
# 1                                False  ...                   False
# 2                                False  ...                    True
# 3                                False  ...                   False
# 4                                 True  ...                   False
# ..                                 ...  ...                     ...
# 995                              False  ...                    True
# 996                              False  ...                   False
# 997                              False  ...                   False
# 998                              False  ...                   False
# 999                              False  ...                   False
#
#      num_dependents_low  num_dependents_medium  num_dependents_high  \
# 0                  True                  False                False
# 1                  True                  False                False
# 2                 False                  False                 True
# 3                 False                  False                 True
# 4                 False                  False                 True
# ..                  ...                    ...                  ...
# 995                True                  False                False
# 996                True                  False                False
# 997                True                  False                False
# 998                True                  False                False
# 999                True                  False                False
#
#      own_telephone_none  own_telephone_yes  foreign_worker_no  \
# 0                 False               True              False
# 1                  True              False              False
# 2                  True              False              False
# 3                  True              False              False
# 4                  True              False              False
# ..                  ...                ...                ...
# 995                True              False              False
# 996               False               True              False
# 997                True              False              False
# 998               False               True              False
# 999                True              False              False
#
#      foreign_worker_yes  class_bad  class_good
# 0                  True      False        True
# 1                  True       True       False
# 2                  True      False        True
# 3                  True      False        True
# 4                  True       True       False
# ..                  ...        ...         ...
# 995                True      False        True
# 996                True      False        True
# 997                True      False        True
# 998                True       True       False
# 999                True      False        True
#
# [1000 rows x 77 columns]

# %%
frequent_itemsets = apriori(data_dummies, min_support=0.7, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets.sort_values(by='support', ascending=False).head(10)
# Out:
#     support                                           itemsets  length
# 5     0.966                             (existing_credits_low)       1
# 7     0.963                               (foreign_worker_yes)       1
# 24    0.930         (existing_credits_low, foreign_worker_yes)       2
# 2     0.907                               (other_parties_none)       1
# 20    0.880           (foreign_worker_yes, other_parties_none)       2
# 18    0.874         (existing_credits_low, other_parties_none)       2
# 1     0.865                                (credit_amount_low)       1
# 36    0.848  (existing_credits_low, foreign_worker_yes, oth...       3
# 6     0.845                               (num_dependents_low)       1
# 14    0.835          (existing_credits_low, credit_amount_low)       2
